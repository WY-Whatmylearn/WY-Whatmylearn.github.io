# %% [markdown]
# ![image.png](attachment:image.png)

# %%
str1 = "hello python"
str2 = '我的名字是"大西瓜"'
print(str2)
# Out:
# 我的名字是"大西瓜"

# %% [markdown]
# # 索引与遍历

# %%
str1[0]
# Out:
# 'h'

# %%
for c in str1:
    print(c)
# Out:
# h
# e
# l
# l
# o
#
# p
# y
# t
# h
# o
# n

# %% [markdown]
# # 字符串操作

# %% [markdown]
# ### 统计字符串长度

# %%
len(str1)
# Out:
# 12

# %% [markdown]
# ### 统计大字符串中小字符(子字符串）串次数

# %%
str1.count("h")
# Out:
# 2

# %% [markdown]
# ### 判断子字符串出现的位置

# %%
str1.index("h")
# Out:
# 0

# %%
str1.index("llo")
# Out:
# 2

# %%
str1.index("a") #如果不存在会报错
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18816/3443769097.py in <module>
# ----> 1 str1.index("a") #如果不存在会报错
#
# ValueError: substring not found

# %% [markdown]
# # 字符串包含的函数
# ![image.png](attachment:image.png)

# %%
# 1.判断空白符
str = " "
str.isspace()
# Out:
# True

# %%
str3 = "1"
print(str3.isdecimal())        
print(str3.isdigit())
print(str3.isnumeric())
# Out:
# True
# True
# True

# %%
str3 = "1.1"
print(str3.isdecimal())        #都不能判断小数
print(str3.isdigit())
print(str3.isnumeric())
# Out:
# False
# False
# False

# %%
str3 = "\u00b2"
print(str3)
print(str3.isdecimal())       
print(str3.isdigit())
print(str3.isnumeric())
# Out:
# ²
# False
# True
# True

# %%
str3 = "1一"
print(str3.isdecimal())
print(str3.isdigit())
print(str3.isnumeric())
# Out:
# False
# False
# True

# %% [markdown]
# 给你一个字符串 sentence 作为句子并指定检索词为 searchWord ，其中句子由若干用 单个空格 分隔的单词组成。请你检查检索词 searchWord 是否为句子 sentence 中任意单词的前缀。
# 如果 searchWord 是某一个单词的前缀，则返回句子 sentence 中该单词所对应的下标（下标从 1 开始）。如果 searchWord 是多个单词的前缀，则返回匹配的第一个单词的下标（最小下标）。如果 searchWord 不是任何单词的前缀，则返回 -1 。
# 字符串 s 的 前缀 是 s 的任何前导连续子字符串

# %%
class Solution:
    def isPrefixOfWord(self, sentence: str, searchWord: str) -> int:
        sentence2 = sentence.split(" ")
        for i in range(1,len(sentence2)+1):
            if sentence2[i-1].startswith(searchWord):
                return i
        return -1

# %%
class Solution:
    def isPrefixOfWord(self, sentence: str, searchWord: str) -> int:
        for num, word in enumerate(sentence.split(), 1):
            if word.startswith(searchWord):
                return num
        return -1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
str = "hello"
str.index("llo")
# Out:
# 2

# %%
str = "hello"
str.index("abc")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8172/2847632496.py in <module>
#       1 str = "hello"
# ----> 2 str.index("abc")
#
# ValueError: substring not found

# %%
str = "hello"
str.find("abc")
# Out:
# -1

# %%
str.replace("hello","hi")
# Out:
# 'hi'

# %%
str              #replace执行完会返回新的字符串，原有的字符串不会被修改
# Out:
# 'hello'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 文本对齐
poem = ["静夜思",
    "床前明月光",
   "疑是地上霜"]
for poem_str in poem:
    print("|%s|"%(poem_str.ljust(10,"　")))
# Out:
# |静夜思　　　　　　　|
# |床前明月光　　　　　|
# |疑是地上霜　　　　　|

# %%
# 去除空白字符
a = "  1 23"
c= a.lstrip()
d = c.split(" ")
d
# Out:
# ['1', '23']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = "1,2 "
a.split(",")
b =  "鹅\t 鹅鹅鹅 \t\n 曲项向天歌 "
b.strip()
b.split()
# Out:
# ['鹅', '鹅鹅鹅', '曲项向天歌']

# %%
s = "fly me   to   the moon  "
s1 = s.split(" ")
s1
# Out:
# ['', '', '', 'fly', 'me', '', '', 'to', '', '', 'the', 'moon', '', '']

# %%
"".join(b) # pycharm中实现
# Out:
# '鹅\t 鹅鹅鹅 \t\n 曲项向天歌 '

# %% [markdown]
# # 字符串的切片

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = "0123456789"
a[2:6]
# Out:
# '2345'

# %%
a[2:]
# Out:
# '23456789'

# %%
a[:6]
# Out:
# '012345'

# %%
a[:]
# Out:
# '0123456789'

# %%
a[::2]
# Out:
# '02468'

# %%
a[1::2]
# Out:
# '13579'

# %%
a[-1]
# Out:
# '9'

# %%
a[2:-1]
# Out:
# '2345678'

# %%
a[-2:]
# Out:
# '89'

# %%
a[-1::-1]
# Out:
# '9876543210'
