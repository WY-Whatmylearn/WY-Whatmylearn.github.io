# %% [markdown]
# # 1.内存的工作原理

# %% [markdown]
# ## 假设你去看演出，需要将东西寄存。寄存处有一个柜子，柜子里有很多抽屉。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2.数组和链表

# %% [markdown]
# ## 链表的缺点：
